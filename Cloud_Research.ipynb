# %%
import os
os.environ['OPENAI_API_KEY'] = 'sk-j8V5OTqGZ0rbPEPn1gK8bqU4BqEfBGEezLnIc2t34LT3BlbkFJPzbbFEtLP0q8qeyV_9Bzkt4nW7bhhqLJ7t4BR5GScA'

# %%
from langchain.llms import OpenAI

llm = OpenAI(temperature = 0.6)

name = llm("provide a cloud provider name for secure workloads")
print(name)
# Out:
# /var/folders/57/jx47mnzx2klgfh446wl0xv0c0000gn/T/ipykernel_84257/954117591.py:3: LangChainDeprecationWarning: The class `OpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAI``.
#   llm = OpenAI(temperature = 0.6)
# /var/folders/57/jx47mnzx2klgfh446wl0xv0c0000gn/T/ipykernel_84257/954117591.py:5: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   name = llm("provide a cloud provider name for secure workloads")
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[2], line 5
#       1 from langchain.llms import OpenAI
# ...
